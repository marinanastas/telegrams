# %%
import pandas as pd

# %%
tg = pd.read_excel('./all_telegrams.xlsx')

# %%
tg = tg.fillna("NA")

# %% [markdown]
# **Проставление координат для географии**

# %%
tg.insert(9, "sent_lat", "")
tg.insert(10, "sent_lon", "")
tg.insert(11, "received_lat", "")
tg.insert(12, "received_lon", "")

# %%
for index, row in tg.iterrows():
    if "Москва" in row["sending_place"]:
        row["sent_lat"] = 55.7522200
        row["sent_lon"] = 37.6155600
    if "Москва" in row["receiving_place"]:
        row["received_lat"] = 55.7522200
        row["received_lon"] = 37.6155600

    if "г. Ленинград" in row["sending_place"]:
        row["sent_lat"] = 59.9386300
        row["sent_lon"] = 30.3141300
    if "г. Ленинград" in row["receiving_place"]:
        row["received_lat"] = 59.9386300
        row["received_lon"] = 30.3141300
    if "г. Санкт-Петербург" in row["sending_place"]:
        row["sent_lat"] = 59.9386300
        row["sent_lon"] = 30.3141300
    if "г. Санкт-Петербург" in row["receiving_place"]:
        row["received_lat"] = 59.9386300
        row["received_lon"] = 30.3141300
    if "г. Петроград" in row["sending_place"]:
        row["sent_lat"] = 59.9386300
        row["sent_lon"] = 30.3141300
    if "г. Петроград" in row["receiving_place"]:
        row["received_lat"] = 59.9386300
        row["received_lon"] = 30.3141300

    if "Горький" in row["sending_place"]:
        row["sent_lat"] = 56.3286700
        row["sent_lon"] = 44.0020500
    if "Горький" in row["receiving_place"]:
        row["received_lat"] = 56.3286700
        row["received_lon"] = 44.0020500
    if "Нижний Новгород" in row["sending_place"]:
        row["sent_lat"] = 56.3286700
        row["sent_lon"] = 44.0020500
    if "Нижний Новгород" in row["receiving_place"]:
        row["received_lat"] = 56.3286700
        row["received_lon"] = 44.0020500

    if "г. Новосибирск" in row["sending_place"]:
        row["sent_lat"] = 55.0415000
        row["sent_lon"] = 82.9346000
    if "г. Новосибирск" in row["receiving_place"]:
        row["received_lat"] = 55.0415000
        row["received_lon"] = 82.9346000
    
    if "г. Красноярск" in row["sending_place"]:
        row["sent_lat"] = 56.0183900
        row["sent_lon"] = 92.8671700
    if "г. Красноярск" in row["receiving_place"]:
        row["received_lat"] = 56.0183900
        row["received_lon"] = 92.8671700

    if "г. Киев" in row["sending_place"]:
        row["sent_lat"] = 50.4546600
        row["sent_lon"] = 30.5238000
    if "г. Киев" in row["receiving_place"]:
        row["received_lat"] = 50.4546600
        row["received_lon"] = 30.5238000

    if "г. Свердловск" in row["sending_place"]:
        row["sent_lat"] = 56.8519000
        row["sent_lon"] = 60.6122000
    if "г. Свердловск" in row["receiving_place"]:
        row["received_lat"] = 56.8519000
        row["received_lon"] = 60.6122000
    if "г. Екатеринбург" in row["sending_place"]:
        row["sent_lat"] = 56.8519000
        row["sent_lon"] = 60.6122000
    if "г. Екатеринбург" in row["receiving_place"]:
        row["received_lat"] = 56.8519000
        row["received_lon"] = 60.6122000

    if "г. Сталинград" in row["sending_place"]:
        row["sent_lat"] = 48.7193900
        row["sent_lon"] = 44.5018300
    if "г. Сталинград" in row["receiving_place"]:
        row["received_lat"] = 48.7193900
        row["received_lon"] = 44.5018300
    if "г. Волгоград" in row["sending_place"]:
        row["sent_lat"] = 48.7193900
        row["sent_lon"] = 44.5018300
    if "г. Волгоград" in row["receiving_place"]:
        row["received_lat"] = 48.7193900
        row["received_lon"] = 44.5018300

    if "г. Харьков" in row["sending_place"]:
        row["sent_lat"] = 49.9808100
        row["sent_lon"] = 36.2527200
    if "г. Харьков" in row["receiving_place"]:
        row["received_lat"] = 49.9808100
        row["received_lon"] = 36.2527200

    if "г. Смоленск" in row["sending_place"]:
        row["sent_lat"] = 54.7818000
        row["sent_lon"] = 32.0401000
    if "г. Смоленск" in row["receiving_place"]:
        row["received_lat"] = 54.7818000
        row["received_lon"] = 32.0401000

    if "г. Казань" in row["sending_place"]:
        row["sent_lat"] = 55.7887400
        row["sent_lon"] = 49.1221400
    if "г. Казань" in row["receiving_place"]:
        row["received_lat"] = 55.7887400
        row["received_lon"] = 49.1221400

    if "г. Челябинск" in row["sending_place"]:
        row["sent_lat"] = 55.1540200
        row["sent_lon"] = 61.4291500
    if "г. Челябинск" in row["receiving_place"]:
        row["received_lat"] = 55.1540200
        row["received_lon"] = 61.4291500

    if "г. Иркутск" in row["sending_place"]:
        row["sent_lat"] = 52.2977800
        row["sent_lon"] = 104.2963900
    if "г. Иркутск" in row["receiving_place"]:
        row["received_lat"] = 52.2977800
        row["received_lon"] = 104.2963900

    # Куйбышев -- бывш. Самара в Самарской области; Каинск -- бывш. Куйбышев в Новосибирской обл.
    # координаты Самары (бывш. Куйбышев)
    if "РСФСР, г. Куйбышев" in row["sending_place"]:
        row["sent_lat"] = 53.2000700
        row["sent_lon"] = 50.1500000
    if "РСФСР, г. Куйбышев" in row["receiving_place"]:
        row["received_lat"] = 53.2000700
        row["received_lon"] = 50.1500000
    if "г. Самара" in row["sending_place"]:
        row["sent_lat"] = 53.2000700
        row["sent_lon"] = 50.1500000
    if "г. Самара" in row["receiving_place"]:
        row["received_lat"] = 53.2000700
        row["received_lon"] = 50.1500000
    # координаты Куйбышева (бывш. Каинск)
    if "г. Каинск" in row["sending_place"]:
        row["sent_lat"] = 55.4475300
        row["sent_lon"] = 78.3218100
    if "г. Каинск" in row["receiving_place"]:
        row["received_lat"] = 55.4475300
        row["received_lon"] = 78.3218100

    if "г. Воронеж" in row["sending_place"]:
        row["sent_lat"] = 51.6720400
        row["sent_lon"] = 39.1843000
    if "г. Воронеж" in row["receiving_place"]:
        row["received_lat"] = 55.4475300
        row["received_lon"] = 39.1843000
    
    if "г. Саратов" in row["sending_place"]:
        row["sent_lat"] = 51.5405600
        row["sent_lon"] = 46.0086100
    if "г. Саратов" in row["receiving_place"]:
        row["received_lat"] = 51.5405600
        row["received_lon"] = 46.0086100

    if "г. Минск" in row["sending_place"]:
        row["sent_lat"] = 53.9000000
        row["sent_lon"] = 27.5666700
    if "г. Минск" in row["receiving_place"]:
        row["received_lat"] = 53.9000000
        row["received_lon"] = 27.5666700

    if "г. Одесса" in row["sending_place"]:
        row["sent_lat"] = 46.4774700
        row["sent_lon"] = 30.7326200
    if "г. Одесса" in row["receiving_place"]:
        row["received_lat"] = 46.4774700
        row["received_lon"] = 30.7326200

    if "г. Сочи" in row["sending_place"]:
        row["sent_lat"] = 43.5991700
        row["sent_lon"] = 39.7256900
    if "г. Сочи" in row["receiving_place"]:
        row["received_lat"] = 43.5991700
        row["received_lon"] = 39.7256900

    if "г. Клин" in row["sending_place"]:
        row["sent_lat"] = 56.3333300
        row["sent_lon"] = 36.7333300
    if "г. Клин" in row["receiving_place"]:
        row["received_lat"] = 56.3333300
        row["received_lon"] = 36.7333300

    if "г. Ростов-на-Дону" in row["sending_place"]:
        row["sent_lat"] = 47.2313500
        row["sent_lon"] = 39.7232800
    if "г. Ростов-на-Дону" in row["receiving_place"]:
        row["received_lat"] = 47.2313500
        row["received_lon"] = 39.7232800

    if "г. Арзамас" in row["sending_place"]:
        row["sent_lat"] = 55.3948500
        row["sent_lon"] = 43.8399200
    if "г. Арзамас" in row["receiving_place"]:
        row["received_lat"] = 55.3948500
        row["received_lon"] = 43.8399200

    # Сталинск -- бывш. Новокузнецк; раньше был в Новосибирской обл., сейчас в Кемеровской; в телеграммах есть и то, и другое
    if "г. Сталинск" in row["sending_place"]:
        row["sent_lat"] = 53.7557000
        row["sent_lon"] = 87.1099000
    if "г. Сталинск" in row["receiving_place"]:
        row["received_lat"] = 53.7557000
        row["received_lon"] = 87.1099000
    if "г. Новокузнецк" in row["sending_place"]:
        row["sent_lat"] = 53.7557000
        row["sent_lon"] = 87.1099000
    if "г. Новокузнецк" in row["receiving_place"]:
        row["received_lat"] = 53.7557000
        row["received_lon"] = 87.1099000

    if "г. Макеевка" in row["sending_place"]:
        row["sent_lat"] = 48.0478200
        row["sent_lon"] = 37.9257600
    if "г. Макеевка" in row["receiving_place"]:
        row["received_lat"] = 48.0478200
        row["received_lon"] = 37.9257600

    if "г. Минусинск" in row["sending_place"]:
        row["sent_lat"] = 53.7102800
        row["sent_lon"] = 91.6875000
    if "г. Минусинск" in row["receiving_place"]:
        row["received_lat"] = 53.7102800
        row["received_lon"] = 91.6875000

    if "г. Красноуральск" in row["sending_place"]:
        row["sent_lat"] = 58.3638000
        row["sent_lon"] = 60.0407000
    if "г. Красноуральск" in row["receiving_place"]:
        row["received_lat"] = 58.3638000
        row["received_lon"] = 60.0407000

    # Сталино - бывш. Донецк
    if "г. Сталино" in row["sending_place"]:
        row["sent_lat"] = 48.0230000
        row["sent_lon"] = 37.8022400
    if "г. Сталино" in row["receiving_place"]:
        row["received_lat"] = 48.0230000
        row["received_lon"] = 37.8022400

    if "г. Барнаул" in row["sending_place"]:
        row["sent_lat"] = 53.3605600
        row["sent_lon"] = 83.7636100
    if "г. Барнаул" in row["receiving_place"]:
        row["received_lat"] = 53.3605600
        row["received_lon"] = 83.7636100

    if "г. Якутск" in row["sending_place"]:
        row["sent_lat"] = 62.0338900
        row["sent_lon"] = 129.7330600
    if "г. Якутск" in row["receiving_place"]:
        row["received_lat"] = 62.0338900
        row["received_lon"] = 129.7330600

    if "г. Кемерово" in row["sending_place"]:
        row["sent_lat"] = 55.3333300
        row["sent_lon"] = 86.0833300
    if "г. Кемерово" in row["receiving_place"]:
        row["received_lat"] = 55.3333300
        row["received_lon"] = 86.0833300

    if "г. Баку" in row["sending_place"]:
        row["sent_lat"] = 40.3776700
        row["sent_lon"] = 49.8920100
    if "г. Баку" in row["receiving_place"]:
        row["received_lat"] = 40.3776700
        row["received_lon"] = 49.8920100

    if "г. Ставрополь" in row["sending_place"]:
        row["sent_lat"] = 45.0428000
        row["sent_lon"] = 41.9734000
    if "г. Ставрополь" in row["receiving_place"]:
        row["received_lat"] = 45.0428000
        row["received_lon"] = 41.9734000

    if "г. Оренбург" in row["sending_place"]:
        row["sent_lat"] = 51.7727000
        row["sent_lon"] = 55.0988000
    if "г. Оренбург" in row["receiving_place"]:
        row["received_lat"] = 51.7727000
        row["received_lon"] = 55.0988000

    if "г. Таганрог" in row["sending_place"]:
        row["sent_lat"] = 47.2361700
        row["sent_lon"] = 38.8968800
    if "г. Таганрог" in row["receiving_place"]:
        row["received_lat"] = 47.2361700
        row["received_lon"] = 38.8968800

    if "с. Курово" in row["sending_place"]:
        row["sent_lat"] = 52.5338170
        row["sent_lon"] = 33.2798930
    if "с. Курово" in row["receiving_place"]:
        row["received_lat"] = 52.5338170
        row["received_lon"] = 33.2798930

    if "г. Киров" in row["sending_place"]:
        row["sent_lat"] = 58.5966500
        row["sent_lon"] = 49.6600700
    if "г. Киров" in row["receiving_place"]:
        row["received_lat"] = 58.5966500
        row["received_lon"] = 49.6600700

    if "г. Муром" in row["sending_place"]:
        row["sent_lat"] = 55.5750000
        row["sent_lon"] = 42.0426000
    if "г. Муром" in row["receiving_place"]:
        row["received_lat"] = 55.5750000
        row["received_lon"] = 42.0426000

    if "г. Краснотурьинск" in row["sending_place"]:
        row["sent_lat"] = 59.7666000
        row["sent_lon"] = 60.2086000
    if "г. Краснотурьинск" in row["receiving_place"]:
        row["received_lat"] = 59.7666000
        row["received_lon"] = 60.2086000

    if "г. Томск" in row["sending_place"]:
        row["sent_lat"] = 56.4977100
        row["sent_lon"] = 84.9743700
    if "г. Томск" in row["receiving_place"]:
        row["received_lat"] = 56.4977100
        row["received_lon"] = 84.9743700

    if "с. Бурла" in row["sending_place"]:
        row["sent_lat"] = 53.3362000
        row["sent_lon"] = 78.3301000
    if "с. Бурла" in row["receiving_place"]:
        row["received_lat"] = 53.3362000
        row["received_lon"] = 78.3301000

    if "г. Шепетовка" in row["sending_place"]:
        row["sent_lat"] = 50.1854500
        row["sent_lon"] = 27.0636500
    if "г. Шепетовка" in row["receiving_place"]:
        row["received_lat"] = 50.1854500
        row["received_lon"] = 27.0636500

    # сейчас это Владимирская область
    if "Ивановская обл., г. Александров" in row["sending_place"]:
        row["sent_lat"] = 56.3951600
        row["sent_lon"] = 38.7121600
    if "Ивановская обл., г. Александров" in row["receiving_place"]:
        row["received_lat"] = 56.3951600
        row["received_lon"] = 38.7121600

    if "г. Киселевск" in row["sending_place"]:
        row["sent_lat"] = 53.9900000
        row["sent_lon"] = 86.6621000
    if "г. Киселевск" in row["receiving_place"]:
        row["received_lat"] = 53.9900000
        row["received_lon"] = 86.6621000

    if "г. Чебаркуль" in row["sending_place"]:
        row["sent_lat"] = 54.9749000
        row["sent_lon"] = 60.3633000
    if "г. Чебаркуль" in row["receiving_place"]:
        row["received_lat"] = 54.9749000
        row["received_lon"] = 60.3633000

    if "г. Ярославль" in row["sending_place"]:
        row["sent_lat"] = 57.6298700
        row["sent_lon"] = 39.8736800
    if "г. Ярославль" in row["receiving_place"]:
        row["received_lat"] = 57.6298700
        row["received_lon"] = 39.8736800

    if "с. Иргиз" in row["sending_place"]:
        row["sent_lat"] = 48.6166700
        row["sent_lon"] = 61.2666700
    if "с. Иргиз" in row["receiving_place"]:
        row["received_lat"] = 48.6166700
        row["received_lon"] = 61.2666700

    if "г. Алма-Ата" in row["sending_place"]:
        row["sent_lat"] = 43.2566700
        row["sent_lon"] = 76.9286100
    if "г. Алма-Ата" in row["receiving_place"]:
        row["received_lat"] = 43.2566700
        row["received_lon"] = 76.9286100

    # Козлов -- бывш. Мичуринск
    if "г. Козлов" in row["sending_place"]:
        row["sent_lat"] = 52.8978000
        row["sent_lon"] = 40.4907000
    if "г. Козлов" in row["receiving_place"]:
        row["received_lat"] = 52.8978000
        row["received_lon"] = 40.4907000

    if "г. Мурманск" in row["sending_place"]:
        row["sent_lat"] = 68.9791700
        row["sent_lon"] = 33.0925100
    if "г. Мурманск" in row["receiving_place"]:
        row["received_lat"] = 68.9791700
        row["received_lon"] = 33.0925100

    if "г. Курск" in row["sending_place"]:
        row["sent_lat"] = 51.7373300
        row["sent_lon"] = 36.1873500
    if "г. Курск" in row["receiving_place"]:
        row["received_lat"] = 51.7373300
        row["received_lon"] = 36.1873500

    if "г. Днепропетровск" in row["sending_place"]:
        row["sent_lat"] = 48.4500000
        row["sent_lon"] = 34.9833300
    if "г. Днепропетровск" in row["receiving_place"]:
        row["received_lat"] = 48.4500000
        row["received_lon"] = 34.9833300

    if "с. Александровка" in row["sending_place"]:
        row["sent_lat"] = 46.7786200
        row["sent_lon"] = 39.0005140
    if "с. Александровка" in row["receiving_place"]:
        row["received_lat"] = 46.7786200
        row["received_lon"] = 39.0005140

    if "г. Верхневилюйск" in row["sending_place"]:
        row["sent_lat"] = 63.4457800
        row["sent_lon"] = 120.3073900
    if "г. Верхневилюйск" in row["receiving_place"]:
        row["received_lat"] = 63.4457800
        row["received_lon"] = 120.3073900

    if "г. Махачкала" in row["sending_place"]:
        row["sent_lat"] = 42.9763800
        row["sent_lon"] = 47.5023600
    if "г. Махачкала" in row["receiving_place"]:
        row["received_lat"] = 42.9763800
        row["received_lon"] = 47.5023600

    if "г. Дзержинск" in row["sending_place"]:
        row["sent_lat"] = 56.2414300
        row["sent_lon"] = 43.4553900
    if "г. Дзержинск" in row["receiving_place"]:
        row["received_lat"] = 56.2414300
        row["received_lon"] = 43.4553900

    if "г. Владикавказ" in row["sending_place"]:
        row["sent_lat"] = 43.0366700
        row["sent_lon"] = 44.6677800
    if "г. Владикавказ" in row["receiving_place"]:
        row["received_lat"] = 43.0366700
        row["received_lon"] = 44.6677800

    if "г. Борисоглебск" in row["sending_place"]:
        row["sent_lat"] = 51.3671300
        row["sent_lon"] = 42.0849400
    if "г. Борисоглебск" in row["receiving_place"]:
        row["received_lat"] = 51.3671300
        row["received_lon"] = 42.0849400

    if "г. Алексеевка" in row["sending_place"]:
        row["sent_lat"] = 50.6309000
        row["sent_lon"] = 38.6903000
    if "г. Алексеевка" in row["receiving_place"]:
        row["received_lat"] = 50.6309000
        row["received_lon"] = 38.6903000

    if "г. Бендеры" in row["sending_place"]:
        row["sent_lat"] = 46.8315600
        row["sent_lon"] = 29.4776900
    if "г. Бендеры" in row["receiving_place"]:
        row["received_lat"] = 46.8315600
        row["received_lon"] = 29.4776900

    if "г. Иваново" in row["sending_place"]:
        row["sent_lat"] = 56.9971900
        row["sent_lon"] = 40.9713900
    if "г. Иваново" in row["receiving_place"]:
        row["received_lat"] = 56.9971900
        row["received_lon"] = 40.9713900

    if "г. Норильск" in row["sending_place"]:
        row["sent_lat"] = 69.3535000
        row["sent_lon"] = 88.2027000
    if "г. Норильск" in row["receiving_place"]:
        row["received_lat"] = 69.3535000
        row["received_lon"] = 88.2027000

    if "г. Кисловодск" in row["sending_place"]:
        row["sent_lat"] = 43.9133300
        row["sent_lon"] = 42.7208300
    if "г. Кисловодск" in row["receiving_place"]:
        row["received_lat"] = 43.9133300
        row["received_lon"] = 42.7208300

    if "г. Краснодар" in row["sending_place"]:
        row["sent_lat"] = 45.0448400
        row["sent_lon"] = 38.9760300
    if "г. Краснодар" in row["receiving_place"]:
        row["received_lat"] = 45.0448400
        row["received_lon"] = 38.9760300

    if "Барвиха" in row["sending_place"]:
        row["sent_lat"] = 55.7421200
        row["sent_lon"] = 37.2792600
    if "Барвиха" in row["receiving_place"]:
        row["received_lat"] = 55.7421200
        row["received_lon"] = 37.2792600

    if "г. Жиганск" in row["sending_place"]:
        row["sent_lat"] = 66.7660100
        row["sent_lon"] = 123.3741800
    if "г. Жиганск" in row["receiving_place"]:
        row["received_lat"] = 66.7660100
        row["received_lon"] = 123.3741800

    if "г. Советск" in row["sending_place"]:
        row["sent_lat"] = 57.5847500
        row["sent_lon"] = 48.9584400
    if "г. Советск" in row["receiving_place"]:
        row["received_lat"] = 57.5847500
        row["received_lon"] = 48.9584400

    if "п. Увельский" in row["sending_place"]:
        row["sent_lat"] = 54.4446000
        row["sent_lon"] = 61.3574000
    if "п. Увельский" in row["receiving_place"]:
        row["received_lat"] = 54.4446000
        row["received_lon"] = 61.3574000

    if "г. Златоуст" in row["sending_place"]:
        row["sent_lat"] = 55.1711100
        row["sent_lon"] = 59.6508300
    if "г. Златоуст" in row["receiving_place"]:
        row["received_lat"] = 55.1711100
        row["received_lon"] = 59.6508300

    if "г. Можайск" in row["sending_place"]:
        row["sent_lat"] = 55.5019400
        row["sent_lon"] = 36.0272200
    if "г. Можайск" in row["receiving_place"]:
        row["received_lat"] = 55.5019400
        row["received_lon"] = 36.0272200

# %%
tg.to_excel("./geography.xlsx")
